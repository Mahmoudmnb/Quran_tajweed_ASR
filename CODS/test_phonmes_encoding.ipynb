# %% [markdown]
# ### تسكين الحرف عند الوقف و همزة الوصل عند بدء الكلام
#
# ### فأذلهما الشيطان   (المد عند الوصل)
#
# ### add silent char
#
# ### add selah to madd eval
#
# ### لِأُولِي  أَنَا
#
# # بِأَييِّكُمُ
#
# # بِاللَّهِ   إِنَّمَا يَعْمُرُ مَسَاجِدَ اللَّٰهِ مَنْ آمَنَ بِاللَّهِ

# %%
import importlib
import phoneme_encoder

importlib.reload(phoneme_encoder) 
phoneme_encoder.test_encoder(for_debug=False)
# Out:
# ====================================================================================================
# correct encoding :
# word : يَسْتَحْيِي => ['ya', 's', 'ta', 'ħ', 'yi', 'yii']
# current encoding :
# word : يَسْتَحْيِي => ['ya', 's', 'ta', 'ħ', 'yii']
# ====================================================================================================
# correct encoding :
# word : يُحْيِيكُمْ => ['yu', 'ħ', 'yi', 'yii', 'ku', 'm']
# current encoding :
# word : يُحْيِيكُمْ => ['yu', 'ħ', 'yii', 'ku', 'm']
# ====================================================================================================
# correct encoding :
# word : يُحْيِي => ['yu', 'ħ', 'yi', 'yii']
# current encoding :
# word : يُحْيِي => ['yu', 'ħ', 'yii']

# %%
import importlib
import phoneme_encoder

importlib.reload(phoneme_encoder)

ph, meta = phoneme_encoder.text_to_phonemes_with_mapping("يَسْتَحْيِي")

ph
# Out:
# --- STEP ---
# i=0, char='ي'
# phonemes so far: []
# [BASE] char=ي → base=y
# [EMIT] ي + a → ya
#
# --- STEP ---
# i=2, char='س'
# phonemes so far: ['ya']
# [BASE] char=س → base=s
#
# --- STEP ---
# i=4, char='ت'
# phonemes so far: ['ya', 's']
# [BASE] char=ت → base=t
# [EMIT] ت + a → ta
#
# --- STEP ---
# i=6, char='ح'
# phonemes so far: ['ya', 's', 'ta']
# [BASE] char=ح → base=ħ
#
# --- STEP ---
# i=8, char='ي'
# phonemes so far: ['ya', 's', 'ta', 'ħ']
# [BASE] char=ي → base=y
# ['ya', 's', 'ta', 'ħ', 'yii']

# %%
# import generate_quran_phoneme
# import importlib

# importlib.reload(generate_quran_phoneme)

# generate_quran_phoneme.generate_phoneme_dataset()

# generate_quran_phoneme.split_ds()
